# %%
number= 3+7
print("The total is", number)
# Out:
# The total is 10

# %%
Name = "Martin"
print("Hello", Name)
# Out:
# Hello Martin

# %%
for no in range(5):
    print(no)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for letter in Name:
    print(letter)
# Out:
# M
# a
# r
# t
# i
# n

# %%
age = 20

if age<8: print("You can ride for free!")
else: print("You need to buy a ticket!")
if age<18: print("You are eligible for a childs ticket!")
else: print("You are eligible for an adult ticket!")
# Out:
# You need to buy a ticket!
# You are eligible for an adult ticket!

# %%
sentence = "Bananariverfulcaptain"

print("First 3 letters:",sentence[0:3])
print(sentence[:3])
print(sentence[4:8])
print(sentence [4:])
print(sentence[-1])
print(sentence[-4:])
print(sentence[4:][0])
print(sentence[4:][:8])
# Out:
# First 3 letters: Ban
# Ban
# nari
# nariverfulcaptain
# n
# tain
# n
# nariverf
